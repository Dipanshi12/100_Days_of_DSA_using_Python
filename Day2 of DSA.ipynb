# %% [markdown]
# ## Question6- Reverse an array

# %%
arr=[10,20,40,50,70,80]

start=0
end=len(arr) -1

while start < end:
    arr[start],arr[end]=arr[end],arr[start]
    start +=1
    end -=1
print(arr)
# Out:
# [80, 70, 50, 40, 20, 10]

# %% [markdown]
# ## Question 7-Linear Search

# %%
arr=[10,20,40,50,70,80]
key=30
found = False
for i in arr:
    if i == key:
        found = True
        break
if found == True:
 print(f"Element is there!{key}")
else:
 print(f"Element is not there!{key}")
# Out:
# Element is not there!30

# %% [markdown]
# ## Question8-Find duplicate element

# %%
arr = [2, 4, 5, 2, 6, 5, 7]
duplicates=[]
for i in arr:
    if arr.count(i)>1 and i not in duplicates:
     duplicates.append(i)
print("Duplicate Elements are:",duplicates)
# Out:
# Duplicate Elements are: [2, 5]

# %% [markdown]
# ## Question9-Find unique element

# %%
arr = [1, 2, 2, 3, 4, 4, 5]
unique=[]
for i in arr:
    if i not in unique:
        unique.append(i)
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
arr = [1, 2, 2, 3, 4, 4, 5]
unique=list(set(arr))

print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## Question 10-Find Second largest element in an array

# %%
arr=[89,45,67,32,90]
largest=second=float('-inf')
for i in arr:
    if i > largest:
        second=largest
        largest = i
    elif i > second and i !=largest:
        second = i
print(f"The Second largest element is : {second}")
# Out:
# The Second largest element is : 89

# %% [markdown]
# # Conclusion
#
# In this notebook, I practiced important array problems that are commonly asked in coding interviews. I learned how to solve problems using efficient logic instead of relying on built-in functions. The concepts covered include array traversal, finding unique and dupliate values, linear search, reversing an array, finding second largest elements, and understanding time and space complexity.
#
# This practice improved my problem-solving skills and strengthened my understanding of Data Structures and Algorithms (DSA). I will continue solving more array questions to build consistency and prepare for coding interviews.
#
# **Day 2 Completed ✅**
